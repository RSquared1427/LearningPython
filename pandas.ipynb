# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib

# %%
# ?InteractiveShell

# %%
data = pd.read_csv("/Users/rongrongzhang/Dropbox/AIM/IntroToPythonTensorflow/datasets/housing/housing.csv",
                   sep=',', header=0)

# %%
data.head() # Displays the top 5 rows. Accepts an optional int parameter - num. of rows to show
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
data.iloc[:2]
data[:2]
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY

# %%
data.isnull()              # check every cell
len(data.dropna(how="any"))
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# 5          False     False               False        False           False
# 6          False     False               False        False           False
# 7          False     False               False        False           False
# 8          False     False               False        False           False
# 9          False     False               False        False           False
# 10         False     False               False        False           False
# ...

# %%
data.isnull().values.any()
data.isnull().any()
data.isnull().sum(axis=0)
data.isnull().values.sum()
# Out:
# True
# longitude             False
# latitude              False
# housing_median_age    False
# total_rooms           False
# total_bedrooms         True
# population            False
# households            False
# median_income         False
# median_house_value    False
# ocean_proximity       False
# dtype: bool
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64
# 207

# %%
index = data.isnull().any(axis=1)
data[data.isnull().any(axis=1)]
data.fillna(data.mean())[index]
data.interpolate()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# 738      -122.14     37.67                37.0       3342.0             NaN
# 1097     -121.77     39.66                20.0       3759.0             NaN
# 1350     -121.95     38.03                 5.0       5526.0             NaN
# 1456     -121.98     37.96                22.0       2987.0             NaN
# 1493     -122.01     37.94                23.0       3741.0             NaN
# 1606     -122.08     37.88                26.0       2947.0             NaN
# ...

# %%
msk = np.random.rand(len(data)) < 0.8

train = data[msk]
len(train)

test = data[~msk]
len(test)
# Out:
# 16492
# 4148

# %%
s = pd.Series(range(5))
s.where(s>1)
s.mask(s>2)
# Out:
# 0    NaN
# 1    NaN
# 2    2.0
# 3    3.0
# 4    4.0
# dtype: float64
# 0    0.0
# 1    1.0
# 2    2.0
# 3    NaN
# 4    NaN
# dtype: float64

# %%
data.tail() # Similar to head, but displays the last rows
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
# The dimensions of the dataframe as a (rows, cols) tuple
data.shape
# Out:
# (20640, 10)

# %%
# The number of columns. Equal to df.shape[0]
len(data)
# Out:
# 20640

# %%
# An array of the column names
data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %%
# Columns and their types
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object

# %%
# Converts the frame to a two-dimensional table
data.values
# Out:
# array([[-122.23, 37.88, 41.0, ..., 8.3252, 452600.0, 'NEAR BAY'],
#        [-122.22, 37.86, 21.0, ..., 8.3014, 358500.0, 'NEAR BAY'],
#        [-122.24, 37.85, 52.0, ..., 7.2574, 352100.0, 'NEAR BAY'],
#        ...,
#        [-121.22, 39.43, 17.0, ..., 1.7, 92300.0, 'INLAND'],
#        [-121.32, 39.43, 18.0, ..., 1.8672, 84700.0, 'INLAND'],
#        [-121.24, 39.37, 16.0, ..., 2.3886, 89400.0, 'INLAND']],
#       dtype=object)

# %%
# Displays descriptive stats for all columns
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# # Indexing
#
# loc gets rows (or columns) with particular labels from the index.
#
# iloc gets rows (or columns) at particular direct positions in the index (so it only takes integers).

# %%
data.iloc[0:3,1]   # but not data.iloc[0:3][1]
# Out:
# 0    37.88
# 1    37.86
# 2    37.85
# Name: latitude, dtype: float64

# %%
data.loc[-15]          # loc is call by index, there is no index -15
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/rongrongzhang/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /Users/rongrongzhang/anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [-15] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-519d94bdaf7f> in <module>()
# ----> 1 data.loc[-15]
#
# ...

# %%
data.iloc[-5]
# Out:
# longitude            -121.09
# latitude               39.48
# housing_median_age        25
# total_rooms             1665
# total_bedrooms           374
# population               845
# households               330
# median_income         1.5603
# median_house_value     78100
# ocean_proximity       INLAND
# Name: 20635, dtype: object

# %%
data.loc[0]
data.iloc[0]
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object

# %% [markdown]
# .loc selects data only by labels
#
# .loc indexer only selects data by the index or column labels.
#
# There are three different inputs you can use for .loc
#
# * A string
# * A list of strings
# * Slice notation using strings as the start and stop values

# %% [markdown]
# Individual columns can be selected with the [] operator or directly as attributes:

# %%
data.dtypes
# Selects only the column named 'col1';
data.median_income 

# Same as previous
data['median_income'] 

# Select two columns
data[['median_income', 'total_bedrooms']]
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# ocean_proximity        object
# dtype: object
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
# 5        4.0368
# 6        3.6591
# 7        3.1200
# 8        2.0804
# 9        3.6912
# 10       3.2031
# 11       3.2705
# 12       3.0750
# 13       2.6736
# 14       1.9167
# 15       2.1250
# 16       2.7750
# 17       2.1202
# 18       1.9911
# 19       2.6033
# 20       1.3578
# 21       1.7135
# 22       1.7250
# 23       2.1806
# 24       2.6000
# 25       2.4038
# 26       2.4597
# 27       1.8080
# 28       1.6424
# 29       1.6875
#           ...
# 20610    1.3631
# 20611    1.2857
# 20612    1.4934
# 20613    1.4958
# 20614    2.4695
# 20615    2.3598
# ...

# %% [markdown]
# Most often, we need to select by a condition on the cell values. To do so, we provide a boolean array denoting which rows will be selected. The trick is that pandas predefines many boolean operators for its data frames and series. For example the following expression produces a boolean array:

# %%
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
data.median_income > 4
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
# 5         True
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 20610    False
# 20611    False
# 20612    False
# 20613    False
# 20614    False
# 20615    False
# 20616    False
# 20617    False
# 20618    False
# 20619    False
# 20620     True
# 20621    False
# 20622    False
# 20623    False
# 20624    False
# 20625     True
# 20626    False
# 20627    False
# 20628    False
# 20629    False
# 20630    False
# 20631    False
# 20632    False
# 20633    False
# 20634    False
# 20635    False
# 20636    False
# ...

# %%
data[data.median_income > 4]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 61       -122.29     37.82                49.0        135.0            29.0
# 105      -122.24     37.82                52.0       1509.0           225.0
# 110      -122.25     37.82                52.0       1424.0           289.0
# 118      -122.23     37.84                50.0       2515.0           399.0
# 119      -122.23     37.84                47.0       3175.0           454.0
# 120      -122.24     37.83                41.0       2576.0           406.0
# ...

# %%
# Query by a single column, if it is in a list of predefined values
data[data['ocean_proximity'].isin(['NEAR BAY', 'INLAND'])]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
# A conjunction query using two columns
data[(data['median_income'] > 5) & (data['ocean_proximity'] == 'NEAR BAY')] 

# A disjunction query using two columns
data[(data['median_income'] > 5) | (data['ocean_proximity'] == 'NEAR BAY')]

# A query checking the textual content of the cells
data[data.ocean_proximity.str.contains('BAY')]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 61       -122.29     37.82                49.0        135.0            29.0
# 110      -122.25     37.82                52.0       1424.0           289.0
# 118      -122.23     37.84                50.0       2515.0           399.0
# 119      -122.23     37.84                47.0       3175.0           454.0
# 120      -122.24     37.83                41.0       2576.0           406.0
# 122      -122.23     37.85                52.0       2800.0           411.0
# 123      -122.24     37.84                52.0       3529.0           574.0
# ...

# %% [markdown]
# ## Sorting
#
# The sort_index method is used to sort the frame by one of its axis indices. The axis is either 0 or 1 - row/column axis respectively:

# %%
# Sort rows descendingly by the index
data1 = data.sort_index(axis=0, ascending=False)
data1.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20639    -121.24     39.37                16.0       2785.0           616.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20635    -121.09     39.48                25.0       1665.0           374.0
#
#        population  households  median_income  median_house_value  \
# 20639      1387.0       530.0         2.3886             89400.0
# 20638       741.0       349.0         1.8672             84700.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20636       356.0       114.0         2.5568             77100.0
# 20635       845.0       330.0         1.5603             78100.0
#
#       ocean_proximity
# 20639          INLAND
# 20638          INLAND
# 20637          INLAND
# 20636          INLAND
# ...

# %%
data1.loc[0]     # call by index
data.loc[0]
data1.iloc[0]           # call by position
# Out:
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object
# longitude              -122.23
# latitude                 37.88
# housing_median_age          41
# total_rooms                880
# total_bedrooms             129
# population                 322
# households                 126
# median_income           8.3252
# median_house_value      452600
# ocean_proximity       NEAR BAY
# Name: 0, dtype: object
# longitude            -121.24
# latitude               39.37
# housing_median_age        16
# total_rooms             2785
# total_bedrooms           616
# population              1387
# households               530
# median_income         2.3886
# median_house_value     89400
# ...

# %%
# We can also sort by one or multiple columns:
data.sort_values(by=['median_income'], ascending=False)
# Out:
#        index  longitude  latitude  housing_median_age  total_rooms  \
# 4352    4352    -118.37     34.10                37.0        407.0
# 10673  10673    -117.85     33.62                13.0       5192.0
# 8849    8849    -118.40     34.08                52.0       3815.0
# 4606    4606    -118.33     34.07                52.0       1482.0
# 5257    5257    -118.49     34.06                42.0       2861.0
# 6399    6399    -118.04     34.13                35.0        249.0
# 4605    4605    -118.33     34.07                52.0       2248.0
# 5281    5281    -118.49     34.05                42.0       1918.0
# 6736    6736    -118.10     34.13                47.0       2234.0
# 15693  15693    -122.44     37.79                52.0       1447.0
# 17166  17166    -122.22     37.40                32.0       2297.0
# 8850    8850    -118.41     34.09                37.0       2716.0
# 16910  16910    -122.36     37.56                32.0       4684.0
# ...

# %%
data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069608    0.099773    0.055310      -0.015176
# latitude                 -0.066983   -0.108785   -0.071035      -0.079809
# ...

# %%
data.sort_index(axis=1, ascending=True)  # order by name alphabetically
# Out:
#        households  housing_median_age  latitude  longitude  \
# 0           126.0                41.0     37.88    -122.23
# 1          1138.0                21.0     37.86    -122.22
# 2           177.0                52.0     37.85    -122.24
# 3           219.0                52.0     37.85    -122.25
# 4           259.0                52.0     37.85    -122.25
# 5           193.0                52.0     37.85    -122.25
# 6           514.0                52.0     37.84    -122.25
# 7           647.0                52.0     37.84    -122.25
# 8           595.0                42.0     37.84    -122.26
# 9           714.0                52.0     37.84    -122.25
# 10          402.0                52.0     37.85    -122.26
# 11          734.0                52.0     37.85    -122.26
# 12          468.0                52.0     37.85    -122.26
# 13          174.0                52.0     37.84    -122.26
# 14          620.0                52.0     37.85    -122.26
# ...

# %% [markdown]
# # Modifying Data Frames
#
# Pandas’ operations tend to produce new data frames instead of modifying the provided ones. Many operations have the optional boolean inplace parameter which we can use to force pandas to apply the changes to subject data frame.
#
# It is also possible to directly assign manipulate the values in cells, columns, and selections as follows:

# %% [markdown]
# # at - label based
#
# Works very similar to loc for scalar indexers. **_Cannot operate on array indexers_**. Can! assign new indices and columns.
#
# * Advantage over loc is that this is faster.
# * Disadvantage is that you can't use arrays for indexers.

# %%
data.at[0, 'median_income']   # first one is row index, second one is colomn index
# data.at[0:1, 'median_income'] is wrong
# Out:
# 8.3252

# %% [markdown]
# # iat - position based
#
# Works similarly to iloc. Cannot work in array indexers. Cannot! assign new indices and columns.
#
# * Advantage over iloc is that this is faster.
# * Disadvantage is that you can't use arrays for indexers.

# %%
data.iat[0,0]
# Out:
# -122.23

# %%
# Modifies the cell identified by its row index and column name
data.head(1)
data.at[0, 'ocean_proximity'] = 'HAHA' 
data.head(1)
data.loc[0, 'ocean_proximity'] = 'HELLO'
data.head(1)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0            HAHA
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0            HAHA
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0           HELLO

# %%
data.index
# Out:
# RangeIndex(start=0, stop=20640, step=1)

# %% [markdown]
# # Add new column

# %%
# Replaces the column with the array. It could be a numpy array or a simple list.
# Could also be used to create new columns
data.loc[:,'index2'] = ['Unknown'] * len(data)

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0           HELLO
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#     index2
# 0  Unknown
# 1  Unknown
# 2  Unknown
# 3  Unknown
# ...

# %%
# Removes all rows with any missing values.
data.dropna(axis=0, how='any')    # any : if any NA values are present, drop that label

# Removes all columns with any missing values.
data.dropna(axis=1, how='any')    # any : if any NA values are present, drop that label

# Removes all rows with all missing values.
data.dropna(axis=0, how='all')    # all : if all values are NA, drop that label
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 8        -122.26     37.84                42.0       2555.0           665.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# 10       -122.26     37.85                52.0       2202.0           434.0
# ...

# %%
#data.drop('bb',axis = 1, inplace=True)
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0           HELLO
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#     index2  avg_rooms
# 0  Unknown   6.984127
# 1  Unknown   6.238137
# ...

# %% [markdown]
# # Different ways to add new column

# %%
data['avg_rooms'] = data.total_rooms / data.households
data.at[:, 'avg_rooms'] = data.total_rooms / data.households
data.loc[:, 'avg_rooms'] = data.total_rooms / data.households

# %%
def g(x, y):
    return x / y

# %%
data.loc[:,'avg_room'] = g(data.total_rooms, data.households)
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0           HELLO
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#     index2  avg_rooms  avg_roomsaa  avg_room
# ...

# %%
data.drop('avg_room', axis=1, inplace=True)    # drop columns

# data.drop(1, axis=0, inplace=True)

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0           HELLO
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#     index2  avg_rooms
# 0  Unknown   6.984127
# 1  Unknown   6.238137
# ...

# %%
data.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x11cf1fe08>

# %%
for index, row in data.iterrows():
    if(index % 10000 == 0): 
        print(index)
        print("~~~~~~~~~~~~~~~~~~~~~")
        print(row)
# Out:
# 0
# ~~~~~~~~~~~~~~~~~~~~~
# longitude             -122.23
# latitude                37.88
# housing_median_age         41
# total_rooms               880
# total_bedrooms            129
# population                322
# households                126
# median_income          8.3252
# median_house_value     452600
# ocean_proximity         HELLO
# index2                Unknown
# avg_rooms             6.98413
# Name: 0, dtype: object
# 10000
# ~~~~~~~~~~~~~~~~~~~~~
# longitude             -121.08
# latitude                39.02
# housing_median_age         13
# total_rooms              1839
# total_bedrooms            275
# population                752
# households                270
# median_income          4.2031
# median_house_value     209600
# ocean_proximity        INLAND
# index2                Unknown
# avg_rooms             6.81111
# Name: 10000, dtype: object
# 20000
# ~~~~~~~~~~~~~~~~~~~~~
# longitude              -119.4
# latitude                36.04
# ...

# %% [markdown]
# Data frames have a method called plot.
#
# By default, it plots a line chart with al numerical columns. The x-axis is the row index of the data frame. In other words, you’re plotting :

# %%
data.plot()

# %%
data.median_income.plot()

# %% [markdown]
# kind : str
#    * 'line' : line plot (default)
#    * 'bar' : vertical bar plot
#    * 'barh' : horizontal bar plot
#    * 'hist' : histogram
#    * 'box' : boxplot
#    * 'kde' : Kernel Density Estimation plot
#    * 'density' : same as 'kde'
#    * 'area' : area plot
#    * 'pie' : pie plot
#    * 'scatter' : scatter plot
#    * 'hexbin' : hexbin plot

# %%
data.plot( x='median_income', y='median_house_value', kind='scatter')

# %%
data.shape
# Removes all rows with any missing values.
datanew = data.dropna(axis=0, how='any').copy()    # any : if any NA values are present, drop that label
datanew.shape
# Out:
# (20640, 10)
# (20433, 10)

# %%
datanew.loc[:, 'newindex'] = np.arange(0, len(datanew))

# %%
datanew.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    newindex
# 0         0
# 1         1
# 2         2
# 3         3
# ...

# %%
datanew.set_index('newindex', inplace=True)

# %%
datanew.head()
# Out:
#           longitude  latitude  housing_median_age  total_rooms  \
# newindex
# 0           -122.23     37.88                41.0        880.0
# 1           -122.22     37.86                21.0       7099.0
# 2           -122.24     37.85                52.0       1467.0
# 3           -122.25     37.85                52.0       1274.0
# 4           -122.25     37.85                52.0       1627.0
#
#           total_bedrooms  population  households  median_income  \
# newindex
# 0                  129.0       322.0       126.0         8.3252
# 1                 1106.0      2401.0      1138.0         8.3014
# 2                  190.0       496.0       177.0         7.2574
# 3                  235.0       558.0       219.0         5.6431
# 4                  280.0       565.0       259.0         3.8462
#
#           median_house_value ocean_proximity
# newindex
# 0                   452600.0        NEAR BAY
# 1                   358500.0        NEAR BAY
# ...

# %%
len(datanew)
# Out:
# 20433

# %%
data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %%
datanew.reset_index(inplace=True)

# %%
datanew.head()
# Out:
#    newindex  longitude  latitude  housing_median_age  total_rooms  \
# 0         0    -122.23     37.88                41.0        880.0
# 1         1    -122.22     37.86                21.0       7099.0
# 2         2    -122.24     37.85                52.0       1467.0
# 3         3    -122.25     37.85                52.0       1274.0
# 4         4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity
# 0        NEAR BAY
# 1        NEAR BAY
# 2        NEAR BAY
# 3        NEAR BAY
# ...

# %%
data.ocean_proximity.value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %%
def mapOceanProximity(x):
    if x == "<1H OCEAN":
        return 0
    elif x == "INLAND":
        return 1
    elif x == "NEAR OCEAN":
        return 2
    elif x == "NEAR BAY":
        return 3
    else: 
        return 4

data['oceanIndex'] = data.ocean_proximity.apply(mapOceanProximity)

# %%
data.head()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity  oceanIndex
# 0        NEAR BAY           3
# 1        NEAR BAY           3
# ...

# %%
data.oceanIndex.value_counts()
# Out:
# 0    9136
# 1    6551
# 2    2658
# 3    2290
# 4       5
# Name: oceanIndex, dtype: int64

# %%
data["IncomeClass"] = data.median_income.apply(lambda x: "rich" if x > 8 else "poor")
data.head()
data.IncomeClass.value_counts()
# Out:
#    index  longitude  latitude  housing_median_age  total_rooms  \
# 0      0    -122.23     37.88                41.0        880.0
# 1      1    -122.22     37.86                21.0       7099.0
# 2      2    -122.24     37.85                52.0       1467.0
# 3      3    -122.25     37.85                52.0       1274.0
# 4      4    -122.25     37.85                52.0       1627.0
#
#    total_bedrooms  population  households  median_income  median_house_value  \
# 0           129.0       322.0       126.0         8.3252            452600.0
# 1          1106.0      2401.0      1138.0         8.3014            358500.0
# 2           190.0       496.0       177.0         7.2574            352100.0
# 3           235.0       558.0       219.0         5.6431            341300.0
# 4           280.0       565.0       259.0         3.8462            342200.0
#
#   ocean_proximity  oceanIndex IncomeClass
# 0        NEAR BAY           3        rich
# ...

# %% [markdown]
# # Merge

# %% [markdown]
# # Union, concatenation

# %% [markdown]
# pd.concat(objs, axis=0, join='outer', join_axes=None, ignore_index=False,
#           keys=None, levels=None, names=None, verify_integrity=False,
#           copy=True)
#
# * axis : {0, 1, ...}, default 0. The axis to concatenate along.
# * join : {‘inner’, ‘outer’}, default ‘outer’. How to handle indexes on other axis(es). Outer for union and inner for intersection.

# %%
df1 = pd.DataFrame({'a': np.random.randn(3), 'b': np.square(range(100,103))})
df1
df2 = pd.DataFrame({'a': [np.NaN, 11, 99], 'c': np.random.randn(3)})
df2
df3 = pd.DataFrame({'a': [np.NaN, 11, 99], 'b': np.random.randn(3)})
df3

pd.concat([df1, df3], keys=['df1', 'df3'])   # note that the indexes are the same
pd.concat([df1, df2], keys=['df1', 'df2'])   # note that the indexes are not the same
# Out:
#           a      b
# 0 -0.037040  10000
# 1 -0.212236  10201
# 2 -0.378815  10404
#       a         c
# 0   NaN -0.519305
# 1  11.0  0.868985
# 2  99.0 -0.308854
#       a         b
# 0   NaN  0.116760
# 1  11.0 -1.575270
# 2  99.0  0.081745
#                a             b
# df1 0  -0.037040  10000.000000
#     1  -0.212236  10201.000000
#     2  -0.378815  10404.000000
# df3 0        NaN      0.116760
#     1  11.000000     -1.575270
#     2  99.000000      0.081745
#                a        b         c
# df1 0  -0.037040  10000.0       NaN
#     1  -0.212236  10201.0       NaN
#     2  -0.378815  10404.0       NaN
# df2 0        NaN      NaN -0.519305
#     1  11.000000      NaN  0.868985
#     2  99.000000      NaN -0.308854

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                   'C': ['C4', 'C5', 'C6', 'C7'],
                   'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

frames = [df1, df2, df3]

result = pd.concat(frames)
result
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df1.append(df2)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df1.append([df2, df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                 'D': ['D2', 'D3', 'D6', 'D7'],
                 'F': ['F2', 'F3', 'F6', 'F7']},
                index=[2, 3, 6, 7])
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %%
pd.concat([df1, df4])
pd.concat([df1, df4], ignore_index=True)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 2  NaN  B2  NaN  D2   F2
# 3  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %%
df1
df4
pd.concat([df1, df4], axis=1)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %%
pd.concat([df1, df4], axis=1, join='inner')  # intersection by index
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# # group

# %%
data.groupby('ocean_proximity').size()
data.groupby('ocean_proximity').mean()
data.groupby('ocean_proximity').sum()
data.groupby('ocean_proximity').max()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# ISLAND           5
# NEAR BAY      2290
# NEAR OCEAN    2658
# dtype: int64
#                         index   longitude   latitude  housing_median_age  \
# ocean_proximity
# <1H OCEAN         9677.915061 -118.847766  34.560577           29.279225
# INLAND           10747.659289 -119.732990  36.731829           24.271867
# ISLAND            8316.000000 -118.354000  33.358000           42.400000
# NEAR BAY          7163.447162 -122.260694  37.801057           37.730131
# NEAR OCEAN       14192.346877 -119.332555  34.738439           29.347254
#
#                  total_rooms  total_bedrooms   population  households  \
# ocean_proximity
# <1H OCEAN        2628.343586      546.539185  1520.290499  517.744965
# INLAND           2717.742787      533.881619  1391.046252  477.447565
# ISLAND           1574.600000      420.400000   668.000000  276.600000
# NEAR BAY         2493.589520      514.182819  1230.317467  488.616157
# ...

# %%
data.groupby('ocean_proximity')['median_income'].mean().sort_values(ascending=True)
# Out:
# ocean_proximity
# ISLAND        2.744420
# INLAND        3.208996
# NEAR OCEAN    4.005785
# NEAR BAY      4.172885
# <1H OCEAN     4.230682
# Name: median_income, dtype: float64

# %% [markdown]
# Count of unique housing_median_age with mean and median median_house_value by ocean_proximity

# %%
data.groupby('ocean_proximity').agg({'housing_median_age': pd.Series.nunique, 'median_house_value': [np.mean, np.median]})
# Out:
#                 housing_median_age median_house_value
#                            nunique               mean    median
# ocean_proximity
# <1H OCEAN                     51.0      240084.285464  214850.0
# INLAND                        52.0      124805.392001  108500.0
# ISLAND                         3.0      380440.000000  414700.0
# NEAR BAY                      51.0      259212.311790  233800.0
# NEAR OCEAN                    51.0      249433.977427  229450.0

# %%
data.groupby('ocean_proximity').agg(['min', 'max'])
data.groupby('ocean_proximity').median_income.agg(['min', 'max'])
# Out:
#                 index        longitude         latitude         \
#                   min    max       min     max      min    max
# ocean_proximity
# <1H OCEAN         701  20506   -124.14 -116.62    32.61  41.88
# INLAND            954  20639   -123.73 -114.31    32.64  41.95
# ISLAND           8314   8318   -118.48 -118.32    33.33  33.43
# NEAR BAY            0  19104   -122.59 -122.01    37.35  38.34
# NEAR OCEAN       1850  20425   -124.35 -116.97    32.54  41.95
#
#                 housing_median_age       total_rooms           ...   \
#                                min   max         min      max  ...
# ocean_proximity                                                ...
# <1H OCEAN                      2.0  52.0        11.0  37937.0  ...
# INLAND                         1.0  52.0         2.0  39320.0  ...
# ISLAND                        27.0  52.0       716.0   2359.0  ...
# NEAR BAY                       2.0  52.0         8.0  18634.0  ...
# ...

# %%
data.groupby('ocean_proximity').agg({'median_income': ['min', 'max'], 'total_rooms': np.max})
# Out:
#                 median_income          total_rooms
#                           min      max        amax
# ocean_proximity
# <1H OCEAN              0.4999  15.0001     37937.0
# INLAND                 0.4999  15.0001     39320.0
# ISLAND                 2.1579   3.3906      2359.0
# NEAR BAY               0.4999  15.0001     18634.0
# NEAR OCEAN             0.5360  15.0001     30405.0

# %%
data.median_income.hist(figsize=(16,8), bins=100)

# %%
tmp = data.groupby(['ocean_proximity', 'IncomeClass']).size()

# %%
tmp.unstack()
# Out:
# IncomeClass        poor   rich
# ocean_proximity
# <1H OCEAN        8724.0  412.0
# INLAND           6495.0   56.0
# ISLAND              5.0    NaN
# NEAR BAY         2182.0  108.0
# NEAR OCEAN       2544.0  114.0

# %%
frame = pd.DataFrame(
    [
        [1,2],
        ["Boris Yeltsin", "Mikhail Gorbachev"]
    ],
    index=["row1", "row2"],
    columns=["column1", "column2"]
)
frame
# Out:
#             column1            column2
# row1              1                  2
# row2  Boris Yeltsin  Mikhail Gorbachev

# %%
frame = pd.DataFrame(
    {
        "column1": [1, "Boris Yeltsin"],
        "column2": [2, "Mikhail Gorbachev"]
    }
)
frame
# Out:
#          column1            column2
# 0              1                  2
# 1  Boris Yeltsin  Mikhail Gorbachev

# %%
data.mean()    # default axis is 0
data.mean(axis=1)
data.std()
# Out:
# index                  10319.500000
# longitude               -119.569704
# latitude                  35.631861
# housing_median_age        28.639486
# total_rooms             2635.763081
# total_bedrooms           537.870553
# population              1425.476744
# households               499.539680
# median_income              3.870671
# median_house_value    206855.816909
# oceanIndex                 0.908769
# dtype: float64
# 0        41274.997745
# 1        33653.903764
# 2        32219.078855
# 3        31233.203918
# 4        31355.404200
# 5        24674.330618
# 6        27619.295373
# 7        22452.337273
# 8        21062.878218
# 9        24327.661927
# 10       25948.344827
# 11       22570.714591
# 12       19819.696818
# 13       17517.477600
# 14       14935.227882
# 15       12940.883182
# 16       14175.123182
# 17       14360.154564
# 18       14799.233736
# 19       15059.833936
# 20       13544.539800
# 21       14825.844864
# 22       10760.390455
# ...

# %%
data.corr()
# Out:
#                        index  longitude  latitude  housing_median_age  \
# index               1.000000  -0.113254  0.081062           -0.181132
# longitude          -0.113254   1.000000 -0.924664           -0.108197
# latitude            0.081062  -0.924664  1.000000            0.011173
# housing_median_age -0.181132  -0.108197  0.011173            1.000000
# total_rooms         0.061896   0.044568 -0.036100           -0.361262
# total_bedrooms      0.032098   0.069608 -0.066983           -0.320451
# population          0.024880   0.099773 -0.108785           -0.296244
# households          0.030186   0.055310 -0.071035           -0.302916
# median_income       0.071673  -0.015176 -0.079809           -0.119034
# median_house_value  0.072086  -0.045967 -0.144160            0.105623
# oceanIndex          0.013525  -0.439870  0.390957            0.145163
#
#                     total_rooms  total_bedrooms  population  households  \
# ...

# %%
data.count()                         # counts the number of non-null values in each DataFrame column.
# Out:
# index                 20640
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# median_house_value    20640
# ocean_proximity       20640
# oceanIndex            20640
# IncomeClass           20640
# dtype: int64

# %% [markdown]
# # Merge

# %% [markdown]
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
#          left_index=False, right_index=False, sort=True,
#          suffixes=('_x', '_y'), copy=True, indicator=False,
#          validate=None)
#
# * left: A DataFrame object
# * right: Another DataFrame object
# * on: Columns (names) to join on. Must be found in both the left and right DataFrame objects. If not passed and left_index and right_index are False, the intersection of the columns in the DataFrames will be inferred to be the join keys
# * left_on: Columns from the left DataFrame to use as keys. Can either be column names or arrays with length equal to the length of the DataFrame
# * right_on: Columns from the right DataFrame to use as keys. Can either be column names or arrays with length equal to the length of the DataFrame
# * left_index: If True, use the index (row labels) from the left DataFrame as its join key(s). In the case of a DataFrame with a MultiIndex (hierarchical), the number of levels must match the number of join keys from the right DataFrame
# * right_index: Same usage as left_index for the right DataFrame
# * how: One of 'left', 'right', 'outer', 'inner'. Defaults to inner. See below for more detailed description of each method
# * sort: Sort the result DataFrame by the join keys in lexicographical order. Defaults to True, setting to False will improve performance substantially in many cases
# * suffixes: A tuple of string suffixes to apply to overlapping columns. Defaults to ('_x', '_y').
# * copy: Always copy data (default True) from the passed DataFrame objects, even when reindexing is not necessary. Cannot be avoided in many cases but may improve performance / memory usage. The cases where copying can be avoided are somewhat pathological but this option is provided nonetheless.
# * indicator: Add a column to the output DataFrame called _merge with information on the source of each row. _merge is Categorical-type and takes on a value of left_only for observations whose merge key only appears in 'left' DataFrame, right_only for observations whose merge key only appears in 'right' DataFrame, and both if the observation’s merge key is found in both.

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                      'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

right
left
pd.merge(left, right, on='key')
pd.concat([left, right], axis=1)

pd.merge(left, right, on='key1')

pd.merge(left, right, on='key2')
# Out:
#     C   D key key1 key2
# 0  C0  D0  K0   K0   K0
# 1  C1  D1  K1   K1   K0
# 2  C2  D2  K2   K1   K0
# 3  C3  D3  K3   K2   K0
#     A   B key key1 key2
# 0  A0  B0  K0   K0   K0
# 1  A1  B1  K1   K0   K1
# 2  A2  B2  K2   K1   K0
# 3  A3  B3  K3   K2   K1
#     A   B key key1_x key2_x   C   D key1_y key2_y
# 0  A0  B0  K0     K0     K0  C0  D0     K0     K0
# 1  A1  B1  K1     K0     K1  C1  D1     K1     K0
# 2  A2  B2  K2     K1     K0  C2  D2     K1     K0
# 3  A3  B3  K3     K2     K1  C3  D3     K2     K0
#     A   B key key1 key2   C   D key key1 key2
# 0  A0  B0  K0   K0   K0  C0  D0  K0   K0   K0
# 1  A1  B1  K1   K0   K1  C1  D1  K1   K1   K0
# 2  A2  B2  K2   K1   K0  C2  D2  K2   K1   K0
# 3  A3  B3  K3   K2   K1  C3  D3  K3   K2   K0
#     A   B key_x key1 key2_x   C   D key_y key2_y
# 0  A0  B0    K0   K0     K0  C0  D0    K0     K0
# 1  A1  B1    K1   K0     K1  C0  D0    K0     K0
# 2  A2  B2    K2   K1     K0  C1  D1    K1     K0
# ...

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#     A   B key_x key1 key2   C   D key_y
# 0  A0  B0    K0   K0   K0  C0  D0    K0
# 1  A2  B2    K2   K1   K0  C1  D1    K1
# 2  A2  B2    K2   K1   K0  C2  D2    K2

# %% [markdown]
# ### how
# The **how** argument to merge specifies how to determine which keys are to be included in the resulting table. If a key combination does not appear in either the left or right tables, the values in the joined table will be NA. Here is a summary of the how options and their SQL equivalent names:

# %% [markdown]
# |Merge method   | SQL Join Name	| Description|
# | ------------- | ------------- | ------------- |
# |left	|LEFT OUTER JOIN	|Use keys from left frame only|
# |right	|RIGHT OUTER JOIN	|Use keys from right frame only|
# |outer	|FULL OUTER JOIN	|Use union of keys from both frames|
# |inner	|INNER JOIN	Use |intersection of keys from both frames|

# %%
left 
right
pd.merge(left, right, how='left', on=['key1', 'key2'])
# Out:
#     A   B key key1 key2
# 0  A0  B0  K0   K0   K0
# 1  A1  B1  K1   K0   K1
# 2  A2  B2  K2   K1   K0
# 3  A3  B3  K3   K2   K1
#     C   D key key1 key2
# 0  C0  D0  K0   K0   K0
# 1  C1  D1  K1   K1   K0
# 2  C2  D2  K2   K1   K0
# 3  C3  D3  K3   K2   K0
#     A   B key_x key1 key2    C    D key_y
# 0  A0  B0    K0   K0   K0   C0   D0    K0
# 1  A1  B1    K1   K0   K1  NaN  NaN   NaN
# 2  A2  B2    K2   K1   K0   C1   D1    K1
# 3  A2  B2    K2   K1   K0   C2   D2    K2
# 4  A3  B3    K3   K2   K1  NaN  NaN   NaN

# %%
pd.merge(left, right, how='right', on=['key1', 'key2'])
# Out:
#      A    B key_x key1 key2   C   D key_y
# 0   A0   B0    K0   K0   K0  C0  D0    K0
# 1   A2   B2    K2   K1   K0  C1  D1    K1
# 2   A2   B2    K2   K1   K0  C2  D2    K2
# 3  NaN  NaN   NaN   K2   K0  C3  D3    K3

# %%
pd.merge(left, right, how='outer', on=['key1', 'key2'])
# Out:
#      A    B key_x key1 key2    C    D key_y
# 0   A0   B0    K0   K0   K0   C0   D0    K0
# 1   A1   B1    K1   K0   K1  NaN  NaN   NaN
# 2   A2   B2    K2   K1   K0   C1   D1    K1
# 3   A2   B2    K2   K1   K0   C2   D2    K2
# 4   A3   B3    K3   K2   K1  NaN  NaN   NaN
# 5  NaN  NaN   NaN   K2   K0   C3   D3    K3

# %%
pd.merge(left, right, how='inner', on=['key1', 'key2'])
# Out:
#     A   B key_x key1 key2   C   D key_y
# 0  A0  B0    K0   K0   K0  C0  D0    K0
# 1  A2  B2    K2   K1   K0  C1  D1    K1
# 2  A2  B2    K2   K1   K0  C2  D2    K2

# %% [markdown]
# ## Checking for duplicate keys
#
# Users can use the **validate** argument to automatically check whether there are unexpected duplicates in their merge keys. Key uniqueness is checked before merge operations and so should protect against memory overflows. Checking key uniqueness is also a good way to ensure user data structures are as expected.

# %%
left = pd.DataFrame({'A' : [1,2], 'B' : [1, 2]})

right = pd.DataFrame({'A' : [4,5,6], 'B': [2, 2, 2]})

left
right
pd.merge(left, right, on='B', how='outer', validate="one_to_one")
# Out:
#    A  B
# 0  1  1
# 1  2  2
#    A  B
# 0  4  2
# 1  5  2
# 2  6  2
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-121-f0d03812cfb1> in <module>()
#       5 left
#       6 right
# ----> 7 pd.merge(left, right, on='B', how='outer', validate="one_to_one")
#       8 pd.merge(left, right, on='B', how='outer', validate="one_to_many")
#
# /Users/rongrongzhang/anaconda/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      55                          right_index=right_index, sort=sort, suffixes=suffixes,
#      56                          copy=copy, indicator=indicator,
# ---> 57                          validate=validate)
#      58     return op.get_result()
#      59
#
# ...

# %%
pd.merge(left, right, on='B', how='outer', validate="one_to_many", indicator=True)
pd.merge(left, right, on='B', how='outer', validate="one_to_many", indicator='Indicator')
# Out:
#    A_x  B  A_y     _merge
# 0    1  1  NaN  left_only
# 1    2  2  4.0       both
# 2    2  2  5.0       both
# 3    2  2  6.0       both
#    A_x  B  A_y  Indicator
# 0    1  1  NaN  left_only
# 1    2  2  4.0       both
# 2    2  2  5.0       both
# 3    2  2  6.0       both

# %%
left = pd.DataFrame({'key': [1], 'v1': [10]})
right = pd.DataFrame({'key': [1, 2], 'v1': [20, 30]})
left
right
pd.merge(left, right, how='left')
pd.merge(left, right, how='right')
pd.merge(left, right, how='outer') # new index
pd.concat([left, right])           # will keep original index
pd.merge(left, right, how='inner')
pd.merge(left, right, how='outer', on='key')
# Out:
#    key  v1
# 0    1  10
#    key  v1
# 0    1  20
# 1    2  30
#    key  v1
# 0    1  10
#    key  v1
# 0    1  20
# 1    2  30
#    key  v1
# 0    1  10
# 1    1  20
# 2    2  30
#    key  v1
# 0    1  10
# 0    1  20
# 1    2  30
# Empty DataFrame
# Columns: [key, v1]
# Index: []
#    key  v1_x  v1_y
# 0    1  10.0    20
# 1    2   NaN    30

# %% [markdown]
# ## Joining on index

# %% [markdown]
# DataFrame.join is a convenient method for combining the columns of two potentially differently-indexed DataFrames into a single result DataFrame. Here is a very basic example:

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                     index=['K0', 'K1', 'K2'])

right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                      'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

left
right
left.join(right)
left.join(right, how='outer')
print('~~~~~~~~~~~~~~~')

right.join(left)

pd.merge(left, right, left_index=True, right_index=True, how='outer')
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3
# ~~~~~~~~~~~~~~~
#      C   D    A    B
# K0  C0  D0   A0   B0
# K2  C2  D2   A2   B2
# K3  C3  D3  NaN  NaN
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'key': ['K0', 'K1', 'K0', 'K1']})


right = pd.DataFrame({'C': ['C0', 'C1'],
                      'D': ['D0', 'D1']},
                      index=['K0', 'K1'])

left
right
# Out:
#     A   B key
# 0  A0  B0  K0
# 1  A1  B1  K1
# 2  A2  B2  K0
# 3  A3  B3  K1
#      C   D
# K0  C0  D0
# K1  C1  D1

# %%
left.join(right, on="key")
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K0  C0  D0
# 3  A3  B3  K1  C1  D1

# %%
pd.merge(left, right, left_on='key', right_index=True, how='left', sort=True)     # sort by key
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 2  A2  B2  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 3  A3  B3  K1  C1  D1

# %% [markdown]
# ## suffixes
#
# The merge suffixes argument takes a tuple of list of strings to append to overlapping column names in the input DataFrames to disambiguate the result columns:

# %%
left = pd.DataFrame({'k': ['K0', 'K1', 'K2'], 'v': [1, 2, 3]})

right = pd.DataFrame({'k': ['K0', 'K0', 'K3'], 'v': [4, 5, 6]})

pd.merge(left, right, on='k')
# Out:
#     k  v_x  v_y
# 0  K0    1    4
# 1  K0    1    5

# %%
pd.merge(left, right, on='k', suffixes=['_l', '_r'])
# Out:
#     k  v_l  v_r
# 0  K0    1    4
# 1  K0    1    5

# %% [markdown]
# DataFrame.join has lsuffix and rsuffix arguments which behave similarly.

# %%
left.join(right, lsuffix='_l', rsuffix='_r')
# Out:
#   k_l  v_l k_r  v_r
# 0  K0    1  K0    4
# 1  K1    2  K0    5
# 2  K2    3  K3    6

# %%
left = left.set_index('k')

right = right.set_index('k')

left.join(right, lsuffix='_l', rsuffix='_r')
# Out:
#     v_l  v_r
# k
# K0    1  4.0
# K0    1  5.0
# K1    2  NaN
# K2    3  NaN

# %%
url = 'https://raw.github.com/pandas-dev/pandas/master/pandas/tests/data/tips.csv'

tips = pd.read_csv(url)

tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips[tips['time'] == 'Dinner'].head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
is_dinner = tips['time'] == 'Dinner'
is_dinner.value_counts()
# Out:
# True     176
# False     68
# Name: time, dtype: int64

# %%
tips[ (tips['time'] =='Dinner') & (tips['tip'] > 5.00)].head()
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 23       39.42  7.58    Male     No  Sat  Dinner     4
# 44       30.40  5.60    Male     No  Sun  Dinner     4
# 47       32.40  6.00    Male     No  Sun  Dinner     4
# 52       34.81  5.20  Female     No  Sun  Dinner     4
# 59       48.27  6.73    Male     No  Sat  Dinner     4

# %%
tips[ (tips['size'] >= 5 ) | (tips['total_bill'] > 45)].head()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 59        48.27  6.73    Male     No   Sat  Dinner     4
# 125       29.80  4.20  Female     No  Thur   Lunch     6
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 143       27.05  5.00  Female     No  Thur   Lunch     6

# %%
frame = pd.DataFrame({'col1': ['A', 'B', np.NaN, 'C', 'D'],
                      'col2': ['F', np.NaN, 'G', 'H', 'I']})
frame
# Out:
#   col1 col2
# 0    A    F
# 1    B  NaN
# 2  NaN    G
# 3    C    H
# 4    D    I

# %%
frame[frame.col2.isna()]
frame[frame.col2.notna()]
# Out:
#   col1 col2
# 1    B  NaN
#   col1 col2
# 0    A    F
# 2  NaN    G
# 3    C    H
# 4    D    I

# %%
tips.groupby('sex').count()  
# count() applies the function to each column, returning the number of not null records within each.
tips.groupby('sex')['sex'].count()
tips.groupby('sex').size()
# Out:
#         total_bill  tip  smoker  day  time  size
# sex
# Female          87   87      87   87    87    87
# Male           157  157     157  157   157   157
# sex
# Female     87
# Male      157
# Name: sex, dtype: int64
# sex
# Female     87
# Male      157
# dtype: int64

# %%
tips.groupby('day')['tip'].mean()

tips.groupby('day').agg({'tip': np.mean, 'day': np.size})
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64
#            tip  day
# day
# Fri   2.734737   19
# Sat   2.993103   87
# Sun   3.255132   76
# Thur  2.771452   62

# %%
tips.groupby(['smoker','day']).agg({'tip': np.mean, 'size': np.size})
tips.groupby(['smoker','day']).agg({'tip': [np.mean, np.size]})
# Out:
#                   tip  size
# smoker day
# No     Fri   2.812500     4
#        Sat   3.102889    45
#        Sun   3.167895    57
#        Thur  2.673778    45
# Yes    Fri   2.714000    15
#        Sat   2.875476    42
#        Sun   3.516842    19
#        Thur  3.030000    17
#                   tip
#                  mean  size
# smoker day
# No     Fri   2.812500   4.0
#        Sat   3.102889  45.0
#        Sun   3.167895  57.0
#        Thur  2.673778  45.0
# Yes    Fri   2.714000  15.0
#        Sat   2.875476  42.0
#        Sun   3.516842  19.0
#        Thur  3.030000  17.0

# %%
# Top N rows with offset
tips.nlargest(10+5, columns='tip').tail(10)
tips.sort_values('tip', ascending=False).iloc[5:15]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 88        24.71  5.85    Male     No  Thur   Lunch     2
# 181       23.33  5.65    Male    Yes   Sun  Dinner     2
# 44        30.40  5.60    Male     No   Sun  Dinner     4
# 52        34.81  5.20  Female     No   Sun  Dinner     4
# 85        34.83  5.17  Female     No  Thur   Lunch     4
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
#      total_bill   tip     sex smoker   day    time  size
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3
# 183       23.17  6.50    Male    Yes   Sun  Dinner     4
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# ...

# %% [markdown]
# # Top N rows per group

# %% [markdown]
# SELECT * FROM (
#   SELECT
#     t.*,
#     ROW_NUMBER() OVER(PARTITION BY day ORDER BY total_bill DESC) AS rn
#   FROM tips t
# )
# WHERE rn < 3
# ORDER BY day, rn;

# %%
(tips.assign(rnk=tips.groupby(['day'])['total_bill']
                  .rank(method='first', ascending=False))
                  .query('rnk < 3')
                  .sort_values(['day','rnk'])
                  )
# Out:
#      total_bill    tip     sex smoker   day    time  size  rnk
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4  1.0
# 90        28.97   3.00    Male    Yes   Fri  Dinner     2  2.0
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3  1.0
# 212       48.33   9.00    Male     No   Sat  Dinner     4  2.0
# 156       48.17   5.00    Male     No   Sun  Dinner     6  1.0
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3  2.0
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4  1.0
# 142       41.19   5.00    Male     No  Thur   Lunch     5  2.0

# %%
tips.loc[tips['tip'] < 2, 'tip'] *= 2      
# set the dip double for the tip less than 2

# %%
tips[tips.tip<2]
# Out:
# Empty DataFrame
# Columns: [total_bill, tip, sex, smoker, day, time, size]
# Index: []
